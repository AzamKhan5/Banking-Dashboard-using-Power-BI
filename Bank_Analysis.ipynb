# %%
import pandas as pd
import numpy as np  
import mysql.connector
import matplotlib.pyplot as plt
import seaborn as sns

# %%
cnx = mysql.connector.connect(user='root',
                              password='Azam@2003',
                              host='127.0.0.1',
                              port = 3306,
                              )

# %%
query = "SELECT * FROM banking_case.CUSTOMER"

# %%
df = pd.read_sql(query, cnx)
# Out:
# C:\Users\AZAM KHAN\AppData\Local\Temp\ipykernel_18660\1600954950.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, cnx)

# %%
df
# Out:
#      ï»¿Client ID              Name  Age  Location ID Joined Bank  \
# 0        IND81288     Raymond Mills   24        34324  06-05-2019
# 1        IND65833     Julia Spencer   23        42205  10-12-2001
# 2        IND47499    Stephen Murray   27         7314  25-01-2010
# 3        IND72498    Virginia Garza   40        34594  28-03-2019
# 4        IND60181   Melissa Sanders   46        41269  20-07-2012
# ...           ...               ...  ...          ...         ...
# 2995     IND66827         Earl Hall   82         8760  09-10-2014
# 2996     IND40556  Billy Williamson   44        32837  05-02-2009
# 2997     IND72414      Victor Black   70        36088  29-12-2009
# 2998     IND46652       Andrew Ford   56        24871  13-02-2006
# 2999     IND40216        Amy Nguyen   79        38518  08-12-2005
#
#           Banking Contact Nationality                     Occupation  \
# 0          Anthony Torres    American           Safety Technician IV
# ...

# %%
df.describe().T
# Out:
#                            count           mean            std       min  \
# Age                       3000.0      51.039667      19.854760     17.00
# Location ID               3000.0   21563.323000   12462.273017     12.00
# Estimated Income          3000.0  171305.034263  111935.808209  15919.48
# Superannuation Savings    3000.0   25531.599673   16259.950770   1482.03
# Amount of Credit Cards    3000.0       1.463667       0.676387      1.00
# Credit Card Balance       3000.0    3176.206943    2497.094709      1.17
# Bank Loans                3000.0  591386.155487  457557.036334      0.00
# Bank Deposits             3000.0  671560.193923  645716.856875      0.00
# Checking Accounts         3000.0  321092.949127  282079.553893      0.00
# Saving Accounts           3000.0  232908.353483  230007.777498      0.00
# Foreign Currency Account  3000.0   29883.529993   23109.924010     45.00
# Business Lending          3000.0  866759.808407  641230.321823      0.00
# ...

# %%
df.shape
# Out:
# (3000, 25)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 25 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   ï»¿Client ID              3000 non-null   object
#  1   Name                      3000 non-null   object
#  2   Age                       3000 non-null   int64
#  3   Location ID               3000 non-null   int64
#  4   Joined Bank               3000 non-null   object
#  5   Banking Contact           3000 non-null   object
#  6   Nationality               3000 non-null   object
#  7   Occupation                3000 non-null   object
#  8   Fee Structure             3000 non-null   object
#  9   Loyalty Classification    3000 non-null   object
#  10  Estimated Income          3000 non-null   float64
#  11  Superannuation Savings    3000 non-null   float64
#  12  Amount of Credit Cards    3000 non-null   int64
# ...

# %%
cat_col = df[["BRId", "GenderId","Properties Owned", "Risk Weighting", "IAId", "Nationality"	,"Occupation",	"Fee Structure"]]
for col in cat_col.columns:
    print(f"Unique values in {col}: {cat_col[col].nunique()}")
    print(cat_col[col].value_counts())
    print("\n")
# Out:
# Unique values in BRId: 4
# BRId
# 3    1352
# 1     660
# 2     495
# 4     493
# Name: count, dtype: int64
#
#
# Unique values in GenderId: 2
# GenderId
# 2    1512
# 1    1488
# Name: count, dtype: int64
#
#
# Unique values in Properties Owned: 4
# Properties Owned
# 2    777
# 1    776
# 3    742
# 0    705
# Name: count, dtype: int64
#
#
# Unique values in Risk Weighting: 5
# Risk Weighting
# 2    1222
# 1     836
# 3     460
# 4     322
# 5     160
# Name: count, dtype: int64
#
#
# Unique values in IAId: 22
# IAId
# 1     177
# 2     177
# 3     177
# 4     177
# 8     177
# 9     176
# 13    176
# 12    176
# 10    176
# 11    176
# 14    176
# 15    176
# 6      89
# 5      89
# 7      89
# 16     88
# 17     88
# 18     88
# 19     88
# 20     88
# 21     88
# 22     88
# Name: count, dtype: int64
#
#
# Unique values in Nationality: 5
# Nationality
# European      1309
# Asian          754
# American       507
# Australian     254
# African        176
# ...

# %%
for i, col in enumerate(cat_col.columns):
    plt.figure(i)
    sns.countplot(data=cat_col, x=col, hue=df["GenderId"])

# %%
for col in cat_col:
    if col == "Occupation":
        continue
    plt.figure(figsize=(10,5))
    sns.histplot(df[col])
    plt.title(f"Distribution of Occupation Count")
    plt.xlabel(col)
    plt.ylabel("Count")
    plt.show()
